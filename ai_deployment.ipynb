# %%
import os
HF_TOKEN = secret
ROBOFLOW_API_KEY = secret

#os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
#os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")

# %%
# !pip install -q gdown inference-gpu
# !pip install -q git+https://github.com/roboflow/sports.git
# !pip list | grep supervision
# !gdown -O "0bfacc_0.mp4" "https://drive.google.com/uc?id=12TqauVZ9tLAv8kWxTTBFWtgt2hNQ4_ZF"
# !gdown -O "2e57b9_0.mp4" "https://drive.google.com/uc?id=19PGw55V8aA6GZu5-Aac5_9mCy3fNxmEf"
# !gdown -O "08fd33_0.mp4" "https://drive.google.com/uc?id=1OG8K6wqUw9t7lp9ms1M48DxRhwTYciK-"
# !gdown -O "573e61_0.mp4" "https://drive.google.com/uc?id=1yYPKuXbHsCxqjA9G-S6aeR2Kcnos8RPU"
# !gdown -O "121364_0.mp4" "https://drive.google.com/uc?id=1vVwjW1dE1drIdd4ZSILfbCGPD4weoNiu"

# !pip install ipywidgets
# Out:
# [notice] A new release of pip available: 22.3 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# 'grep' is not recognized as an internal or external command,
# operable program or batch file.
# Downloading...
# From: https://drive.google.com/uc?id=12TqauVZ9tLAv8kWxTTBFWtgt2hNQ4_ZF
# To: c:\Users\snell\Downloads\soccer-analytics-yolo\0bfacc_0.mp4
#
#   0%|          | 0.00/19.9M [00:00<?, ?B/s]
#  11%|█         | 2.10M/19.9M [00:00<00:00, 19.3MB/s]
#  29%|██▉       | 5.77M/19.9M [00:00<00:00, 27.3MB/s]
#  55%|█████▌    | 11.0M/19.9M [00:00<00:00, 33.8MB/s]
#  87%|████████▋ | 17.3M/19.9M [00:00<00:00, 33.7MB/s]
# 100%|██████████| 19.9M/19.9M [00:00<00:00, 33.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=19PGw55V8aA6GZu5-Aac5_9mCy3fNxmEf
# To: c:\Users\snell\Downloads\soccer-analytics-yolo\2e57b9_0.mp4
#
#   0%|          | 0.00/21.1M [00:00<?, ?B/s]
#   7%|▋         | 1.57M/21.1M [00:00<00:01, 15.7MB/s]
#  32%|███▏      | 6.82M/21.1M [00:00<00:00, 32.9MB/s]
#  52%|█████▏    | 11.0M/21.1M [00:00<00:00, 29.9MB/s]
#  72%|███████▏  | 15.2M/21.1M [00:00<00:00, 33.1MB/s]
#  97%|█████████▋| 20.4M/21.1M [00:00<00:00, 38.5MB/s]
# 100%|██████████| 21.1M/21.1M [00:00<00:00, 34.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1OG8K6wqUw9t7lp9ms1M48DxRhwTYciK-
# To: c:\Users\snell\Downloads\soccer-analytics-yolo\08fd33_0.mp4
#
#   0%|          | 0.00/19.9M [00:00<?, ?B/s]
#   8%|▊         | 1.57M/19.9M [00:00<00:01, 15.0MB/s]
#  40%|███▉      | 7.86M/19.9M [00:00<00:00, 41.3MB/s]
#  69%|██████▊   | 13.6M/19.9M [00:00<00:00, 47.6MB/s]
# 100%|██████████| 19.9M/19.9M [00:00<00:00, 48.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1yYPKuXbHsCxqjA9G-S6aeR2Kcnos8RPU
# To: c:\Users\snell\Downloads\soccer-analytics-yolo\573e61_0.mp4
#
#   0%|          | 0.00/18.9M [00:00<?, ?B/s]
#  11%|█         | 2.10M/18.9M [00:00<00:00, 19.7MB/s]
#  39%|███▉      | 7.34M/18.9M [00:00<00:00, 37.6MB/s]
#  67%|██████▋   | 12.6M/18.9M [00:00<00:00, 41.4MB/s]
# 100%|██████████| 18.9M/18.9M [00:00<00:00, 44.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1vVwjW1dE1drIdd4ZSILfbCGPD4weoNiu
# To: c:\Users\snell\Downloads\soccer-analytics-yolo\121364_0.mp4
#
#   0%|          | 0.00/17.2M [00:00<?, ?B/s]
#  12%|█▏        | 2.10M/17.2M [00:00<00:00, 18.5MB/s]
#  40%|███▉      | 6.82M/17.2M [00:00<00:00, 33.5MB/s]
#  67%|██████▋   | 11.5M/17.2M [00:00<00:00, 38.5MB/s]
#  94%|█████████▍| 16.3M/17.2M [00:00<00:00, 41.1MB/s]
# 100%|██████████| 17.2M/17.2M [00:00<00:00, 37.7MB/s]
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip available: 22.3 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ipywidgets in c:\users\snell\appdata\roaming\python\python311\site-packages (8.1.7)
# Requirement already satisfied: comm>=0.1.3 in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipywidgets) (9.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: colorama in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\snell\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\snell\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\snell\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\snell\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
import os
os.environ["ONNXRUNTIME_EXECUTION_PROVIDERS"] = "[CUDAExecutionProvider]"
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cpu
# !pip uninstall -y onnxruntime
# !pip uninstall inference -y
# !pip install --upgrade inference
# !pip install 'inference[all]'
# Out:
# ERROR: Exception:
# Found existing installation: torch 2.8.0+cpu
# Traceback (most recent call last):
# Uninstalling torch-2.8.0+cpu:
#   Successfully uninstalled torch-2.8.0+cpu
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_internal\commands\uninstall.py", line 103, in run
#     uninstall_pathset.commit()
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_internal\req\req_uninstall.py", line 424, in commit
#     self._moved_paths.commit()
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_internal\req\req_uninstall.py", line 277, in commit
#     save_dir.cleanup()
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_internal\utils\temp_dir.py", line 173, in cleanup
#     rmtree(self._path)
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_vendor\tenacity\__init__.py", line 328, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_vendor\tenacity\__init__.py", line 408, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_vendor\tenacity\__init__.py", line 364, in iter
#     raise retry_exc.reraise()
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_vendor\tenacity\__init__.py", line 197, in reraise
#     raise self.last_attempt.result()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\concurrent\futures\_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\concurrent\futures\_base.py", line 401, in __get_result
#     raise self._exception
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_vendor\tenacity\__init__.py", line 411, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_internal\utils\misc.py", line 128, in rmtree
#     shutil.rmtree(dir, ignore_errors=ignore_errors, onerror=rmtree_errorhandler)
#   File "C:\Program Files\Python311\Lib\shutil.py", line 758, in rmtree
#     return _rmtree_unsafe(path, onerror)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\shutil.py", line 616, in _rmtree_unsafe
#     _rmtree_unsafe(fullname, onerror)
#   File "C:\Program Files\Python311\Lib\shutil.py", line 621, in _rmtree_unsafe
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "C:\Program Files\Python311\Lib\shutil.py", line 619, in _rmtree_unsafe
#     os.unlink(fullname)
# PermissionError: [WinError 5] Access is denied: 'C:\\Users\\snell\\AppData\\Roaming\\Python\\Python311\\site-packages\\~.rch\\lib\\asmjit.dll'
# Files removed: 9
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# Looking in indexes: https://download.pytorch.org/whl/cpu
# torchaudio 2.5.1+cu121 requires torch==2.5.1+cu121, but you have torch 2.8.0+cpu which is incompatible.
# Collecting torch
#   Obtaining dependency information for torch from https://download.pytorch.org/whl/cpu/torch-2.8.0%2Bcpu-cp311-cp311-win_amd64.whl.metadata
# [notice] A new release of pip available: 22.3 -> 25.2
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.8.0%2Bcpu-cp311-cp311-win_amd64.whl.metadata (29 kB)
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: torchvision in c:\users\snell\appdata\roaming\python\python311\site-packages (0.23.0+cpu)
# Requirement already satisfied: filelock in c:\users\snell\appdata\roaming\python\python311\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\snell\appdata\roaming\python\python311\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in c:\users\snell\appdata\roaming\python\python311\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\snell\appdata\roaming\python\python311\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\snell\appdata\roaming\python\python311\site-packages (from torch) (2025.7.0)
# Requirement already satisfied: numpy in c:\users\snell\appdata\roaming\python\python311\site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from jinja2->torch) (2.1.5)
# Downloading https://download.pytorch.org/whl/cpu/torch-2.8.0%2Bcpu-cp311-cp311-win_amd64.whl (619.4 MB)
#    --------------------------------------- 619.4/619.4 MB 50.4 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torch-2.8.0%2Bcpu-cp311-cp311-win_amd64.whl (619.4 MB)
#    --------------------------------------- 619.4/619.4 MB 54.4 MB/s eta 0:00:00
# Installing collected packages: torch
# Successfully installed torch-2.8.0+cpu
# Found existing installation: onnxruntime 1.21.1
# ERROR: Exception:
# Traceback (most recent call last):
# Uninstalling onnxruntime-1.21.1:
#   Successfully uninstalled onnxruntime-1.21.1
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_internal\commands\uninstall.py", line 103, in run
#     uninstall_pathset.commit()
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_internal\req\req_uninstall.py", line 424, in commit
#     self._moved_paths.commit()
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_internal\req\req_uninstall.py", line 277, in commit
#     save_dir.cleanup()
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_internal\utils\temp_dir.py", line 173, in cleanup
#     rmtree(self._path)
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_vendor\tenacity\__init__.py", line 328, in wrapped_f
#     return self(f, *args, **kw)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_vendor\tenacity\__init__.py", line 408, in __call__
#     do = self.iter(retry_state=retry_state)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_vendor\tenacity\__init__.py", line 364, in iter
#     raise retry_exc.reraise()
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_vendor\tenacity\__init__.py", line 197, in reraise
#     raise self.last_attempt.result()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\concurrent\futures\_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\concurrent\futures\_base.py", line 401, in __get_result
#     raise self._exception
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_vendor\tenacity\__init__.py", line 411, in __call__
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\site-packages\pip\_internal\utils\misc.py", line 128, in rmtree
#     shutil.rmtree(dir, ignore_errors=ignore_errors, onerror=rmtree_errorhandler)
#   File "C:\Program Files\Python311\Lib\shutil.py", line 758, in rmtree
#     return _rmtree_unsafe(path, onerror)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python311\Lib\shutil.py", line 616, in _rmtree_unsafe
#     _rmtree_unsafe(fullname, onerror)
#   File "C:\Program Files\Python311\Lib\shutil.py", line 621, in _rmtree_unsafe
#     onerror(os.unlink, fullname, sys.exc_info())
#   File "C:\Program Files\Python311\Lib\shutil.py", line 619, in _rmtree_unsafe
#     os.unlink(fullname)
# PermissionError: [WinError 5] Access is denied: 'C:\\Users\\snell\\AppData\\Local\\Temp\\pip-uninstall-57fbqdkr\\capi\\onnxruntime_providers_shared.dll'
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip available: 22.3 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: onnxruntime-gpu in c:\users\snell\appdata\roaming\python\python311\site-packages (1.21.1)
# Requirement already satisfied: coloredlogs in c:\users\snell\appdata\roaming\python\python311\site-packages (from onnxruntime-gpu) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\snell\appdata\roaming\python\python311\site-packages (from onnxruntime-gpu) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\snell\appdata\roaming\python\python311\site-packages (from onnxruntime-gpu) (2.2.6)
# Requirement already satisfied: packaging in c:\users\snell\appdata\roaming\python\python311\site-packages (from onnxruntime-gpu) (24.2)
# Requirement already satisfied: protobuf in c:\users\snell\appdata\roaming\python\python311\site-packages (from onnxruntime-gpu) (6.31.1)
# Requirement already satisfied: sympy in c:\users\snell\appdata\roaming\python\python311\site-packages (from onnxruntime-gpu) (1.13.3)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from coloredlogs->onnxruntime-gpu) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from sympy->onnxruntime-gpu) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\snell\appdata\roaming\python\python311\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime-gpu) (3.5.4)
# Found existing installation: inference 0.52.0
# Uninstalling inference-0.52.0:
#   Successfully uninstalled inference-0.52.0
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip available: 22.3 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting inference
#   Downloading inference-0.52.0-py3-none-any.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: aiortc~=1.9.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (1.9.0)
# Requirement already satisfied: APScheduler<4.0.0,>=3.10.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (3.11.0)
# Requirement already satisfied: asyncua~=1.1.5 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (1.1.6)
# Requirement already satisfied: cachetools<6.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (5.5.2)
# Requirement already satisfied: cython~=3.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (3.0.12)
# Requirement already satisfied: python-dotenv~=1.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (1.0.1)
# Requirement already satisfied: fastapi<0.116,>=0.100 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (0.115.14)
# Requirement already satisfied: numpy<2.3.0,>=2.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (2.2.6)
# Requirement already satisfied: opencv-python<=4.10.0.84,>=4.8.1.78 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (4.10.0.84)
# Requirement already satisfied: opencv-contrib-python<=4.10.0.84,>=4.8.1.78 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (4.10.0.84)
# Requirement already satisfied: pillow<12.0,>=11.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (11.3.0)
# Requirement already satisfied: prometheus-fastapi-instrumentator<=6.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (6.0.0)
# Requirement already satisfied: redis~=5.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (5.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (2.32.4)
# Requirement already satisfied: rich<13.10.0,>=13.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (13.9.4)
# Requirement already satisfied: supervision<0.26.0,>=0.25.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (0.25.1)
# Requirement already satisfied: pybase64~=1.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (1.0.2)
# Requirement already satisfied: scikit-image<=0.25.2,>=0.19.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (0.25.2)
# Requirement already satisfied: requests-toolbelt~=1.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (1.0.0)
# Requirement already satisfied: wheel<=0.45.1,>=0.38.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (0.45.1)
# Requirement already satisfied: setuptools>=70.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (80.9.0)
# Requirement already satisfied: networkx<4.0.0,>=3.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (3.5)
# Requirement already satisfied: pydantic<2.12.0,>=2.8.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (2.11.7)
# Requirement already satisfied: pydantic-settings<2.8 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (2.7.1)
# Requirement already satisfied: openai<2.0.0,>=1.12.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (1.97.1)
# Requirement already satisfied: structlog<25.0.0,>=24.1.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (24.4.0)
# Requirement already satisfied: zxing-cpp~=2.2.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (2.2.0)
# Requirement already satisfied: boto3<=1.35.60 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (1.35.60)
# Requirement already satisfied: typing_extensions<=4.12.2,>=4.8.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (4.12.2)
# Requirement already satisfied: pydot~=2.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (2.0.0)
# Requirement already satisfied: shapely<2.1.0,>=2.0.4 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (2.0.7)
# Requirement already satisfied: tldextract~=5.1.2 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (5.1.3)
# Requirement already satisfied: packaging~=24.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (24.2)
# Requirement already satisfied: anthropic~=0.49.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (0.49.0)
# Requirement already satisfied: pandas<3.0.0,>=2.2.3 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (2.3.1)
# Requirement already satisfied: paho-mqtt~=1.6.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (1.6.1)
# Requirement already satisfied: pytest<9.0.0,>=8.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (8.4.1)
# Requirement already satisfied: tokenizers<0.22.0,>=0.19.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (0.21.4)
# Requirement already satisfied: slack-sdk~=3.33.4 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (3.33.5)
# Requirement already satisfied: twilio~=9.3.7 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (9.3.8)
# Requirement already satisfied: httpx~=0.28.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (0.28.1)
# Requirement already satisfied: pylogix==1.0.5 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (1.0.5)
# Requirement already satisfied: pymodbus<=3.8.3,>=3.6.9 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (3.8.3)
# Requirement already satisfied: backoff~=2.2.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (2.2.1)
# Requirement already satisfied: filelock<=3.17.0,>=3.12.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (3.17.0)
# Requirement already satisfied: onvif-zeep-async==2.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (2.0.0)
# Requirement already satisfied: simple-pid~=2.0.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (2.0.1)
# Collecting onnxruntime<1.22.0,>=1.15.1
#   Downloading onnxruntime-1.21.1-cp311-cp311-win_amd64.whl (12.3 MB)
#      --------------------------------------- 12.3/12.3 MB 32.8 MB/s eta 0:00:00
# Requirement already satisfied: nvidia-ml-py<13.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (12.575.51)
# Requirement already satisfied: docker<8.0.0,>=7.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (7.1.0)
# Requirement already satisfied: click<8.2.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (8.1.8)
# Requirement already satisfied: typer<=0.16.0,>=0.9.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (0.16.0)
# Requirement already satisfied: PyYAML~=6.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (6.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (4.67.1)
# Requirement already satisfied: py-cpuinfo~=9.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (9.0.0)
# Requirement already satisfied: aiohttp<=3.10.11,>=3.9.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (3.10.11)
# Requirement already satisfied: dataclasses-json~=0.6.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from inference) (0.6.7)
# Requirement already satisfied: zeep[async]<5.0.0,>=4.2.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from onvif-zeep-async==2.0.0->inference) (4.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (6.6.3)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiohttp<=3.10.11,>=3.9.0->inference) (1.20.1)
# Requirement already satisfied: aioice<1.0.0,>=0.9.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiortc~=1.9.0->inference) (0.10.1)
# Requirement already satisfied: av<13.0.0,>=9.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiortc~=1.9.0->inference) (12.3.0)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiortc~=1.9.0->inference) (1.17.1)
# Requirement already satisfied: cryptography>=42.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiortc~=1.9.0->inference) (45.0.5)
# Requirement already satisfied: google-crc32c>=1.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiortc~=1.9.0->inference) (1.7.1)
# Requirement already satisfied: pyee>=9.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiortc~=1.9.0->inference) (13.0.0)
# Requirement already satisfied: pylibsrtp>=0.10.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiortc~=1.9.0->inference) (0.12.0)
# Requirement already satisfied: pyopenssl>=24.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aiortc~=1.9.0->inference) (25.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from anthropic~=0.49.0->inference) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from anthropic~=0.49.0->inference) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from anthropic~=0.49.0->inference) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\snell\appdata\roaming\python\python311\site-packages (from anthropic~=0.49.0->inference) (1.3.1)
# Requirement already satisfied: tzlocal>=3.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from APScheduler<4.0.0,>=3.10.1->inference) (5.3.1)
# Requirement already satisfied: aiofiles in c:\users\snell\appdata\roaming\python\python311\site-packages (from asyncua~=1.1.5->inference) (24.1.0)
# Requirement already satisfied: aiosqlite in c:\users\snell\appdata\roaming\python\python311\site-packages (from asyncua~=1.1.5->inference) (0.21.0)
# Requirement already satisfied: python-dateutil in c:\users\snell\appdata\roaming\python\python311\site-packages (from asyncua~=1.1.5->inference) (2.9.0.post0)
# Requirement already satisfied: pytz in c:\users\snell\appdata\roaming\python\python311\site-packages (from asyncua~=1.1.5->inference) (2025.2)
# Requirement already satisfied: sortedcontainers in c:\users\snell\appdata\roaming\python\python311\site-packages (from asyncua~=1.1.5->inference) (2.4.0)
# Requirement already satisfied: wait-for2==0.3.2 in c:\users\snell\appdata\roaming\python\python311\site-packages (from asyncua~=1.1.5->inference) (0.3.2)
# Requirement already satisfied: botocore<1.36.0,>=1.35.60 in c:\users\snell\appdata\roaming\python\python311\site-packages (from boto3<=1.35.60->inference) (1.35.99)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from boto3<=1.35.60->inference) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from boto3<=1.35.60->inference) (0.10.4)
# Requirement already satisfied: colorama in c:\users\snell\appdata\roaming\python\python311\site-packages (from click<8.2.0->inference) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from dataclasses-json~=0.6.0->inference) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from dataclasses-json~=0.6.0->inference) (0.9.0)
# Requirement already satisfied: pywin32>=304 in c:\users\snell\appdata\roaming\python\python311\site-packages (from docker<8.0.0,>=7.0.0->inference) (311)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from docker<8.0.0,>=7.0.0->inference) (2.5.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from fastapi<0.116,>=0.100->inference) (0.46.2)
# Requirement already satisfied: certifi in c:\users\snell\appdata\roaming\python\python311\site-packages (from httpx~=0.28.1->inference) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\snell\appdata\roaming\python\python311\site-packages (from httpx~=0.28.1->inference) (1.0.9)
# Requirement already satisfied: idna in c:\users\snell\appdata\roaming\python\python311\site-packages (from httpx~=0.28.1->inference) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\snell\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx~=0.28.1->inference) (0.16.0)
# Requirement already satisfied: coloredlogs in c:\users\snell\appdata\roaming\python\python311\site-packages (from onnxruntime<1.22.0,>=1.15.1->inference) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\snell\appdata\roaming\python\python311\site-packages (from onnxruntime<1.22.0,>=1.15.1->inference) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\snell\appdata\roaming\python\python311\site-packages (from onnxruntime<1.22.0,>=1.15.1->inference) (6.31.1)
# Requirement already satisfied: sympy in c:\users\snell\appdata\roaming\python\python311\site-packages (from onnxruntime<1.22.0,>=1.15.1->inference) (1.13.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\snell\appdata\roaming\python\python311\site-packages (from pandas<3.0.0,>=2.2.3->inference) (2025.2)
# Requirement already satisfied: prometheus-client<1.0.0,>=0.8.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from prometheus-fastapi-instrumentator<=6.0.0->inference) (0.22.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from pydantic<2.12.0,>=2.8.0->inference) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\snell\appdata\roaming\python\python311\site-packages (from pydantic<2.12.0,>=2.8.0->inference) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from pydantic<2.12.0,>=2.8.0->inference) (0.4.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\snell\appdata\roaming\python\python311\site-packages (from pydot~=2.0.0->inference) (3.2.3)
# Requirement already satisfied: iniconfig>=1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from pytest<9.0.0,>=8.0.0->inference) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\snell\appdata\roaming\python\python311\site-packages (from pytest<9.0.0,>=8.0.0->inference) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\snell\appdata\roaming\python\python311\site-packages (from pytest<9.0.0,>=8.0.0->inference) (2.19.2)
# Requirement already satisfied: async-timeout>=4.0.3 in c:\users\snell\appdata\roaming\python\python311\site-packages (from redis~=5.0.0->inference) (5.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\snell\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.32.0->inference) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from rich<13.10.0,>=13.0.0->inference) (3.0.0)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\snell\appdata\roaming\python\python311\site-packages (from scikit-image<=0.25.2,>=0.19.0->inference) (1.16.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\snell\appdata\roaming\python\python311\site-packages (from scikit-image<=0.25.2,>=0.19.0->inference) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\snell\appdata\roaming\python\python311\site-packages (from scikit-image<=0.25.2,>=0.19.0->inference) (2025.6.11)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\snell\appdata\roaming\python\python311\site-packages (from scikit-image<=0.25.2,>=0.19.0->inference) (0.4)
# Requirement already satisfied: contourpy>=1.0.7 in c:\users\snell\appdata\roaming\python\python311\site-packages (from supervision<0.26.0,>=0.25.1->inference) (1.3.3)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from supervision<0.26.0,>=0.25.1->inference) (0.7.1)
# Requirement already satisfied: matplotlib>=3.6.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from supervision<0.26.0,>=0.25.1->inference) (3.10.3)
# Requirement already satisfied: requests-file>=1.4 in c:\users\snell\appdata\roaming\python\python311\site-packages (from tldextract~=5.1.2->inference) (2.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\snell\appdata\roaming\python\python311\site-packages (from tokenizers<0.22.0,>=0.19.0->inference) (0.34.3)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from twilio~=9.3.7->inference) (2.10.1)
# Requirement already satisfied: aiohttp-retry==2.8.3 in c:\users\snell\appdata\roaming\python\python311\site-packages (from twilio~=9.3.7->inference) (2.8.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from typer<=0.16.0,>=0.9.0->inference) (1.5.4)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aioice<1.0.0,>=0.9.0->aiortc~=1.9.0->inference) (2.7.0)
# Requirement already satisfied: ifaddr>=0.2.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from aioice<1.0.0,>=0.9.0->aiortc~=1.9.0->inference) (0.2.0)
# Requirement already satisfied: pycparser in c:\users\snell\appdata\roaming\python\python311\site-packages (from cffi>=1.0.0->aiortc~=1.9.0->inference) (2.22)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<0.22.0,>=0.19.0->inference) (2025.7.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich<13.10.0,>=13.0.0->inference) (0.1.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\snell\appdata\roaming\python\python311\site-packages (from matplotlib>=3.6.0->supervision<0.26.0,>=0.25.1->inference) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from matplotlib>=3.6.0->supervision<0.26.0,>=0.25.1->inference) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from matplotlib>=3.6.0->supervision<0.26.0,>=0.25.1->inference) (1.4.8)
# Requirement already satisfied: six>=1.5 in c:\users\snell\appdata\roaming\python\python311\site-packages (from python-dateutil->asyncua~=1.1.5->inference) (1.17.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json~=0.6.0->inference) (1.1.0)
# Requirement already satisfied: propcache>=0.2.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from yarl<2.0,>=1.12.0->aiohttp<=3.10.11,>=3.9.0->inference) (0.3.2)
# Requirement already satisfied: isodate>=0.5.4 in c:\users\snell\appdata\roaming\python\python311\site-packages (from zeep[async]<5.0.0,>=4.2.1->onvif-zeep-async==2.0.0->inference) (0.7.2)
# Requirement already satisfied: lxml>=4.6.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from zeep[async]<5.0.0,>=4.2.1->onvif-zeep-async==2.0.0->inference) (6.0.0)
# Requirement already satisfied: platformdirs>=1.4.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from zeep[async]<5.0.0,>=4.2.1->onvif-zeep-async==2.0.0->inference) (4.3.8)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\snell\appdata\roaming\python\python311\site-packages (from coloredlogs->onnxruntime<1.22.0,>=1.15.1->inference) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\snell\appdata\roaming\python\python311\site-packages (from sympy->onnxruntime<1.22.0,>=1.15.1->inference) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\snell\appdata\roaming\python\python311\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime<1.22.0,>=1.15.1->inference) (3.5.4)
# Installing collected packages: onnxruntime, inference
# Successfully installed inference-0.52.0 onnxruntime-1.21.1
# ERROR: Invalid requirement: "'inference[all]'"
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip available: 22.3 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## ball, player, goalkeeper and referee detection

# %%
from inference import get_model

PLAYER_DETECTION_MODEL_ID = "football-players-detection-3zvbc-mwxcp/2"
PLAYER_DETECTION_MODEL = get_model(model_id=PLAYER_DETECTION_MODEL_ID, api_key=ROBOFLOW_API_KEY)

# %%
import supervision as sv

SOURCE_VIDEO_PATH = "121364_0.mp4"

frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)
frame = next(frame_generator)

sv.plot_image(frame)

# %%
from tqdm import tqdm
import supervision as sv

SOURCE_VIDEO_PATH = "121364_0.mp4"
TARGET_VIDEO_PATH = "121364_0_result_1.mp4"

box_annotator = sv.BoxAnnotator(
    color=sv.ColorPalette.from_hex(['#FF8C00', '#00BFFF', '#FF1493', '#FFD700']),
    thickness=2
)
label_annotator = sv.LabelAnnotator(
    color=sv.ColorPalette.from_hex(['#FF8C00', '#00BFFF', '#FF1493', '#FFD700']),
    text_color=sv.Color.from_hex('#000000')
)

video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
video_sink = sv.VideoSink(TARGET_VIDEO_PATH, video_info=video_info)

frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)
frame = next(frame_generator)

with video_sink:
    for frame in tqdm(frame_generator, total=video_info.total_frames):

        result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
        detections = sv.Detections.from_inference(result)

        labels = [
            f"{class_name} {confidence:.2f}"
            for class_name, confidence
            in zip(detections['class_name'], detections.confidence)
        ]

        annotated_frame = frame.copy()
        annotated_frame = box_annotator.annotate(
            scene=annotated_frame,
            detections=detections)
        annotated_frame = label_annotator.annotate(
            scene=annotated_frame,
            detections=detections,
            labels=labels)
        video_sink.write_frame(annotated_frame)

sv.plot_image(annotated_frame)
# Out:
# 100%|█████████▉| 749/750 [41:02<00:03,  3.29s/it]

# %% [markdown]
# ## video game style visualization

# %%
import supervision as sv

SOURCE_VIDEO_PATH = "121364_0.mp4"
BALL_ID = 0

ellipse_annotator = sv.EllipseAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF', '#FF1493', '#FFD700']),
    thickness=2
)
triangle_annotator = sv.TriangleAnnotator(
    color=sv.Color.from_hex('#FFD700'),
    base=25,
    height=21,
    outline_thickness=1
)

frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)
frame = next(frame_generator)

result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
detections = sv.Detections.from_inference(result)

ball_detections = detections[detections.class_id == BALL_ID]
ball_detections.xyxy = sv.pad_boxes(xyxy=ball_detections.xyxy, px=10)

all_detections = detections[detections.class_id != BALL_ID]
all_detections = all_detections.with_nms(threshold=0.5, class_agnostic=True)
all_detections.class_id -= 1

annotated_frame = frame.copy()
annotated_frame = ellipse_annotator.annotate(
    scene=annotated_frame,
    detections=all_detections)
annotated_frame = triangle_annotator.annotate(
    scene=annotated_frame,
    detections=ball_detections)

sv.plot_image(annotated_frame)

# %% [markdown]
# ## player tracking

# %%
import supervision as sv

SOURCE_VIDEO_PATH = "121364_0.mp4"
BALL_ID = 0

ellipse_annotator = sv.EllipseAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF', '#FF1493', '#FFD700']),
    thickness=2
)
label_annotator = sv.LabelAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF', '#FF1493', '#FFD700']),
    text_color=sv.Color.from_hex('#000000'),
    text_position=sv.Position.BOTTOM_CENTER
)
triangle_annotator = sv.TriangleAnnotator(
    color=sv.Color.from_hex('#FFD700'),
    base=25,
    height=21,
    outline_thickness=1
)

tracker = sv.ByteTrack()
tracker.reset()

frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)
frame = next(frame_generator)

result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
detections = sv.Detections.from_inference(result)

ball_detections = detections[detections.class_id == BALL_ID]
ball_detections.xyxy = sv.pad_boxes(xyxy=ball_detections.xyxy, px=10)

all_detections = detections[detections.class_id != BALL_ID]
all_detections = all_detections.with_nms(threshold=0.5, class_agnostic=True)
all_detections.class_id -= 1
all_detections = tracker.update_with_detections(detections=all_detections)

labels = [
    f"#{tracker_id}"
    for tracker_id
    in all_detections.tracker_id
]

annotated_frame = frame.copy()
annotated_frame = ellipse_annotator.annotate(
    scene=annotated_frame,
    detections=all_detections)
annotated_frame = label_annotator.annotate(
    scene=annotated_frame,
    detections=all_detections,
    labels=labels)
annotated_frame = triangle_annotator.annotate(
    scene=annotated_frame,
    detections=ball_detections)

sv.plot_image(annotated_frame)

# %% [markdown]
# ## split players into teams
#
# ![football AI diagram](https://media.roboflow.com/notebooks/examples/football-ai-team-clustering.png)
#
# **Note:** Before training our player clustering model, we need to gather training data. To do this, we'll sample one frame per second, detect players within those frames, and then crop them out.

# %%
from tqdm import tqdm

SOURCE_VIDEO_PATH = "121364_0.mp4"
PLAYER_ID = 2
STRIDE = 30

frame_generator = sv.get_video_frames_generator(
    source_path=SOURCE_VIDEO_PATH, stride=STRIDE)

crops = []
for frame in tqdm(frame_generator, desc='collecting crops'):
    result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
    detections = sv.Detections.from_inference(result)
    detections = detections.with_nms(threshold=0.5, class_agnostic=True)
    detections = detections[detections.class_id == PLAYER_ID]
    players_crops = [sv.crop_image(frame, xyxy) for xyxy in detections.xyxy]
    crops += players_crops

# %% [markdown]
# **Note:** Here's a sample (100 elements) of the crops we've gathered.

# %%
sv.plot_images_grid(crops[:100], grid_size=(10, 10))

# %% [markdown]
# **Note:** Next, we'll run [SigLIP](https://huggingface.co/docs/transformers/en/model_doc/siglip) to calculate embeddings for each of the crops.

# %%
import torch
from transformers import AutoProcessor, SiglipVisionModel

SIGLIP_MODEL_PATH = 'google/siglip-base-patch16-224'

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
EMBEDDINGS_MODEL = SiglipVisionModel.from_pretrained(SIGLIP_MODEL_PATH).to(DEVICE)
EMBEDDINGS_PROCESSOR = AutoProcessor.from_pretrained(SIGLIP_MODEL_PATH)

# %%
import numpy as np
from more_itertools import chunked

BATCH_SIZE = 32

crops = [sv.cv2_to_pillow(crop) for crop in crops]
batches = chunked(crops, BATCH_SIZE)
data = []
with torch.no_grad():
    for batch in tqdm(batches, desc='embedding extraction'):
        inputs = EMBEDDINGS_PROCESSOR(images=batch, return_tensors="pt").to(DEVICE)
        outputs = EMBEDDINGS_MODEL(**inputs)
        embeddings = torch.mean(outputs.last_hidden_state, dim=1).cpu().numpy()
        data.append(embeddings)

data = np.concatenate(data)

# %% [markdown]
# **Note:** Using [UMAP](https://github.com/lmcinnes/umap), we project our embeddings from `(N, 768)` to `(N, 3)` and then perform a two-cluster division using [KMeans](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html).

# %%
import umap
from sklearn.cluster import KMeans

REDUCER = umap.UMAP(n_components=3)
CLUSTERING_MODEL = KMeans(n_clusters=2)

# %%
projections = REDUCER.fit_transform(data)
clusters = CLUSTERING_MODEL.fit_predict(projections)

# %%
#Note: Here's an interactive visualization of our results. Click on a dot to display its associated crop.
import plotly.graph_objects as go
import numpy as np
from typing import Dict, List
from IPython.core.display import display, HTML
from PIL import Image
import base64
from io import BytesIO


def pil_image_to_data_uri(image: Image.Image) -> str:
    buffered = BytesIO()
    image.save(buffered, format="PNG")
    img_str = base64.b64encode(buffered.getvalue()).decode("utf-8")
    return f"data:image/png;base64,{img_str}"


def display_projections(
    labels: np.ndarray,
    projections: np.ndarray,
    images: List[Image.Image],
    show_legend: bool = False,
    show_markers_with_text: bool = True
) -> None:
    image_data_uris = {f"image_{i}": pil_image_to_data_uri(image) for i, image in enumerate(images)}
    image_ids = np.array([f"image_{i}" for i in range(len(images))])

    unique_labels = np.unique(labels)
    traces = []
    for unique_label in unique_labels:
        mask = labels == unique_label
        customdata_masked = image_ids[mask]
        trace = go.Scatter3d(
            x=projections[mask][:, 0],
            y=projections[mask][:, 1],
            z=projections[mask][:, 2],
            mode='markers+text' if show_markers_with_text else 'markers',
            text=labels[mask],
            customdata=customdata_masked,
            name=str(unique_label),
            marker=dict(size=8),
            hovertemplate="<b>class: %{text}</b><br>image ID: %{customdata}<extra></extra>"
        )
        traces.append(trace)

    # Calculate shared range for cube appearance
    all_axes = projections
    min_val = np.min(all_axes)
    max_val = np.max(all_axes)
    padding = (max_val - min_val) * 0.05
    axis_range = [min_val - padding, max_val + padding]

    fig = go.Figure(data=traces)
    fig.update_layout(
        scene=dict(
            xaxis=dict(title='X', range=axis_range),
            yaxis=dict(title='Y', range=axis_range),
            zaxis=dict(title='Z', range=axis_range),
            aspectmode='cube'  # Ensures equal scaling
        ),
        width=1000,
        height=1000,
        showlegend=show_legend
    )

    plotly_div = fig.to_html(full_html=False, include_plotlyjs=False, div_id="scatter-plot-3d")

    javascript_code = f"""
    <script>
        function displayImage(imageId) {{
            var imageElement = document.getElementById('image-display');
            var placeholderText = document.getElementById('placeholder-text');
            var imageDataURIs = {image_data_uris};
            imageElement.src = imageDataURIs[imageId];
            imageElement.style.display = 'block';
            placeholderText.style.display = 'none';
        }}

        var chartElement = document.getElementById('scatter-plot-3d');

        chartElement.on('plotly_click', function(data) {{
            var customdata = data.points[0].customdata;
            displayImage(customdata);
        }});
    </script>
    """

    html_template = f"""
    <!DOCTYPE html>
    <html>
        <head>
            <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
            <style>
                #image-container {{
                    position: fixed;
                    top: 0;
                    left: 0;
                    width: 200px;
                    height: 200px;
                    padding: 5px;
                    border: 1px solid #ccc;
                    background-color: white;
                    z-index: 1000;
                    box-sizing: border-box;
                    display: flex;
                    align-items: center;
                    justify-content: center;
                    text-align: center;
                }}
                #image-display {{
                    width: 100%;
                    height: 100%;
                    object-fit: contain;
                }}
            </style>
        </head>
        <body>
            {plotly_div}
            <div id="image-container">
                <img id="image-display" src="" alt="Selected image" style="display: none;" />
                <p id="placeholder-text">Click on a data entry to display an image</p>
            </div>
            {javascript_code}
        </body>
    </html>
    """

    display(HTML(html_template))

display_projections(clusters, projections, crops)

# %%
#Note:** To simplify the use of the SigLIP, UMAP, and KMeans combo, I've packaged all these models into a [`TeamClassifier`](https://github.com/roboflow/sports/blob/06053616f1f8a8ae1fa936eb00dcdc2e4f888bb1/sports/common/team.py#L41) that you can find in the [sports](https://github.com/roboflow/sports) repository.
import supervision as sv
from tqdm import tqdm
from sports.common.team import TeamClassifier

SOURCE_VIDEO_PATH = "121364_0.mp4"
PLAYER_ID = 2
STRIDE = 30

frame_generator = sv.get_video_frames_generator(
    source_path=SOURCE_VIDEO_PATH, stride=STRIDE)

crops = []
for frame in tqdm(frame_generator, desc='collecting crops'):
    result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
    detections = sv.Detections.from_inference(result)
    players_detections = detections[detections.class_id == PLAYER_ID]
    players_crops = [sv.crop_image(frame, xyxy) for xyxy in detections.xyxy]
    crops += players_crops

team_classifier = TeamClassifier(device="cuda")
team_classifier.fit(crops)

# %%
#Note:** Time to assign goalkeepers to teams. We'll use a simple heuristic: calculate the average position (centroid) of the players belonging to both teams and then assign the goalkeeper to the team whose average position is closer.
import numpy as np
import supervision as sv

def resolve_goalkeepers_team_id(
    players: sv.Detections,
    goalkeepers: sv.Detections
) -> np.ndarray:
    goalkeepers_xy = goalkeepers.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
    players_xy = players.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
    team_0_centroid = players_xy[players.class_id == 0].mean(axis=0)
    team_1_centroid = players_xy[players.class_id == 1].mean(axis=0)
    goalkeepers_team_id = []
    for goalkeeper_xy in goalkeepers_xy:
        dist_0 = np.linalg.norm(goalkeeper_xy - team_0_centroid)
        dist_1 = np.linalg.norm(goalkeeper_xy - team_1_centroid)
        goalkeepers_team_id.append(0 if dist_0 < dist_1 else 1)

    return np.array(goalkeepers_team_id)

# %%
import supervision as sv

SOURCE_VIDEO_PATH = "121364_0.mp4"
BALL_ID = 0
GOALKEEPER_ID = 1
PLAYER_ID = 2
REFEREE_ID = 3

ellipse_annotator = sv.EllipseAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF', '#FF1493', '#FFD700']),
    thickness=2
)
label_annotator = sv.LabelAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF', '#FF1493', '#FFD700']),
    text_color=sv.Color.from_hex('#000000'),
    text_position=sv.Position.BOTTOM_CENTER
)
triangle_annotator = sv.TriangleAnnotator(
    color=sv.Color.from_hex('#FFD700'),
    base=25,
    height=21,
    outline_thickness=1
)

tracker = sv.ByteTrack()
tracker.reset()

frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)
frame = next(frame_generator)

result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
detections = sv.Detections.from_inference(result)

ball_detections = detections[detections.class_id == BALL_ID]
ball_detections.xyxy = sv.pad_boxes(xyxy=ball_detections.xyxy, px=10)

all_detections = detections[detections.class_id != BALL_ID]
all_detections = all_detections.with_nms(threshold=0.5, class_agnostic=True)
all_detections = tracker.update_with_detections(detections=all_detections)

goalkeepers_detections = all_detections[all_detections.class_id == GOALKEEPER_ID]
players_detections = all_detections[all_detections.class_id == PLAYER_ID]
referees_detections = all_detections[all_detections.class_id == REFEREE_ID]

players_crops = [sv.crop_image(frame, xyxy) for xyxy in players_detections.xyxy]
players_detections.class_id = team_classifier.predict(players_crops)

goalkeepers_detections.class_id = resolve_goalkeepers_team_id(
    players_detections, goalkeepers_detections)

referees_detections.class_id -= 1

all_detections = sv.Detections.merge([
    players_detections, goalkeepers_detections, referees_detections])

labels = [
    f"#{tracker_id}"
    for tracker_id
    in all_detections.tracker_id
]

all_detections.class_id = all_detections.class_id.astype(int)

annotated_frame = frame.copy()
annotated_frame = ellipse_annotator.annotate(
    scene=annotated_frame,
    detections=all_detections)
annotated_frame = label_annotator.annotate(
    scene=annotated_frame,
    detections=all_detections,
    labels=labels)
annotated_frame = triangle_annotator.annotate(
    scene=annotated_frame,
    detections=ball_detections)

sv.plot_image(annotated_frame)

# %% [markdown]
# ## Pitch KeyPoint Detection

# %%
from inference import get_model
from google.colab import userdata

ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')
FIELD_DETECTION_MODEL_ID = "football-field-detection-f07vi-e8dgd/1"
FIELD_DETECTION_MODEL = get_model(model_id=FIELD_DETECTION_MODEL_ID, api_key=ROBOFLOW_API_KEY)

# %%
import supervision as sv

SOURCE_VIDEO_PATH = "121364_0.mp4"

vertex_annotator = sv.VertexAnnotator(
    color=sv.Color.from_hex('#FF1493'),
    radius=8)

frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)
frame = next(frame_generator)

result = FIELD_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
key_points = sv.KeyPoints.from_inference(result)

annotated_frame = frame.copy()
annotated_frame = vertex_annotator.annotate(
    scene=annotated_frame,
    key_points=key_points)

sv.plot_image(annotated_frame)

# %% [markdown]
# **Note:** Notice that some of the keypoints we detected are in incorrect locations. These are keypoints with a low confidence level. Let's filter out these keypoints and keep only the ones the model is confident about.

# %% [markdown]
# ## filter low confidence keypoints

# %%
import supervision as sv

SOURCE_VIDEO_PATH = "121364_0.mp4"

vertex_annotator = sv.VertexAnnotator(
    color=sv.Color.from_hex('#FF1493'),
    radius=8)

frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH, start=200)
frame = next(frame_generator)

result = FIELD_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
key_points = sv.KeyPoints.from_inference(result)

filter = key_points.confidence[0] > 0.5
frame_reference_points = key_points.xy[0][filter]
frame_reference_key_points = sv.KeyPoints(
    xy=frame_reference_points[np.newaxis, ...])

annotated_frame = frame.copy()
annotated_frame = vertex_annotator.annotate(
    scene=annotated_frame,
    key_points=frame_reference_key_points)

sv.plot_image(annotated_frame)

# %% [markdown]
# ## project pitch lines on frame

# %% [markdown]
# **Note:** The [sports](https://github.com/roboflow/sports) repository contains a [`SoccerPitchConfiguration`](https://github.com/roboflow/sports/blob/06053616f1f8a8ae1fa936eb00dcdc2e4f888bb1/sports/configs/soccer.py#L6) that provides information about the real-world geometry of the soccer pitch. It also includes utilities for visualizing elements located on the pitch.

# %%
from sports.annotators.soccer import draw_pitch
from sports.configs.soccer import SoccerPitchConfiguration

CONFIG = SoccerPitchConfiguration()

annotated_frame = draw_pitch(CONFIG)

sv.plot_image(annotated_frame)

# %% [markdown]
# **Note:** It's time to utilize the keypoint pairs located on the camera perspective plane and the football pitch plane. The [sports](https://github.com/roboflow/sports) repository includes a [`ViewTransformer`](https://github.com/roboflow/sports/blob/06053616f1f8a8ae1fa936eb00dcdc2e4f888bb1/sports/common/view.py#L7), which employs homography for perspective transformation.

# %%
import numpy as np
import supervision as sv
from sports.common.view import ViewTransformer

SOURCE_VIDEO_PATH = "121364_0.mp4"

edge_annotator = sv.EdgeAnnotator(
    color=sv.Color.from_hex('#00BFFF'),
    thickness=2, edges=CONFIG.edges)
vertex_annotator = sv.VertexAnnotator(
    color=sv.Color.from_hex('#FF1493'),
    radius=8)
vertex_annotator_2 = sv.VertexAnnotator(
    color=sv.Color.from_hex('#00BFFF'),
    radius=8)

frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH, start=200)
frame = next(frame_generator)

result = FIELD_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
key_points = sv.KeyPoints.from_inference(result)

filter = key_points.confidence[0] > 0.5
frame_reference_points = key_points.xy[0][filter]
frame_reference_key_points = sv.KeyPoints(
    xy=frame_reference_points[np.newaxis, ...])

pitch_reference_points = np.array(CONFIG.vertices)[filter]

transformer = ViewTransformer(
    source=pitch_reference_points,
    target=frame_reference_points
)

pitch_all_points = np.array(CONFIG.vertices)
frame_all_points = transformer.transform_points(points=pitch_all_points)

frame_all_key_points = sv.KeyPoints(xy=frame_all_points[np.newaxis, ...])

annotated_frame = frame.copy()
annotated_frame = edge_annotator.annotate(
    scene=annotated_frame,
    key_points=frame_all_key_points)
annotated_frame = vertex_annotator_2.annotate(
    scene=annotated_frame,
    key_points=frame_all_key_points)
annotated_frame = vertex_annotator.annotate(
    scene=annotated_frame,
    key_points=frame_reference_key_points)

sv.plot_image(annotated_frame)

# %% [markdown]
# ## project ball, players and referies on pitch

# %%
import supervision as sv
from tqdm import tqdm
from sports.common.team import TeamClassifier

SOURCE_VIDEO_PATH = "121364_0.mp4"
PLAYER_ID = 2
STRIDE = 30

frame_generator = sv.get_video_frames_generator(
    source_path=SOURCE_VIDEO_PATH, stride=STRIDE)

crops = []
for frame in tqdm(frame_generator, desc='collecting crops'):
    result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
    detections = sv.Detections.from_inference(result)
    players_detections = detections[detections.class_id == PLAYER_ID]
    players_crops = [sv.crop_image(frame, xyxy) for xyxy in detections.xyxy]
    crops += players_crops

team_classifier = TeamClassifier(device="cuda")
team_classifier.fit(crops)

# %%
import cv2
from typing import Optional

def draw_pitch_voronoi_diagram_2(
    config: SoccerPitchConfiguration,
    team_1_xy: np.ndarray,
    team_2_xy: np.ndarray,
    team_1_color: sv.Color = sv.Color.RED,
    team_2_color: sv.Color = sv.Color.WHITE,
    opacity: float = 0.5,
    padding: int = 50,
    scale: float = 0.1,
    pitch: Optional[np.ndarray] = None
) -> np.ndarray:
    """
    Draws a Voronoi diagram on a soccer pitch representing the control areas of two
    teams with smooth color transitions.

    Args:
        config (SoccerPitchConfiguration): Configuration object containing the
            dimensions and layout of the pitch.
        team_1_xy (np.ndarray): Array of (x, y) coordinates representing the positions
            of players in team 1.
        team_2_xy (np.ndarray): Array of (x, y) coordinates representing the positions
            of players in team 2.
        team_1_color (sv.Color, optional): Color representing the control area of
            team 1. Defaults to sv.Color.RED.
        team_2_color (sv.Color, optional): Color representing the control area of
            team 2. Defaults to sv.Color.WHITE.
        opacity (float, optional): Opacity of the Voronoi diagram overlay.
            Defaults to 0.5.
        padding (int, optional): Padding around the pitch in pixels.
            Defaults to 50.
        scale (float, optional): Scaling factor for the pitch dimensions.
            Defaults to 0.1.
        pitch (Optional[np.ndarray], optional): Existing pitch image to draw the
            Voronoi diagram on. If None, a new pitch will be created. Defaults to None.

    Returns:
        np.ndarray: Image of the soccer pitch with the Voronoi diagram overlay.
    """
    if pitch is None:
        pitch = draw_pitch(
            config=config,
            padding=padding,
            scale=scale
        )

    scaled_width = int(config.width * scale)
    scaled_length = int(config.length * scale)

    voronoi = np.zeros_like(pitch, dtype=np.uint8)

    team_1_color_bgr = np.array(team_1_color.as_bgr(), dtype=np.uint8)
    team_2_color_bgr = np.array(team_2_color.as_bgr(), dtype=np.uint8)

    y_coordinates, x_coordinates = np.indices((
        scaled_width + 2 * padding,
        scaled_length + 2 * padding
    ))

    y_coordinates -= padding
    x_coordinates -= padding

    def calculate_distances(xy, x_coordinates, y_coordinates):
        return np.sqrt((xy[:, 0][:, None, None] * scale - x_coordinates) ** 2 +
                       (xy[:, 1][:, None, None] * scale - y_coordinates) ** 2)

    distances_team_1 = calculate_distances(team_1_xy, x_coordinates, y_coordinates)
    distances_team_2 = calculate_distances(team_2_xy, x_coordinates, y_coordinates)

    min_distances_team_1 = np.min(distances_team_1, axis=0)
    min_distances_team_2 = np.min(distances_team_2, axis=0)

    # Increase steepness of the blend effect
    steepness = 15  # Increased steepness for sharper transition
    distance_ratio = min_distances_team_2 / np.clip(min_distances_team_1 + min_distances_team_2, a_min=1e-5, a_max=None)
    blend_factor = np.tanh((distance_ratio - 0.5) * steepness) * 0.5 + 0.5

    # Create the smooth color transition
    for c in range(3):  # Iterate over the B, G, R channels
        voronoi[:, :, c] = (blend_factor * team_1_color_bgr[c] +
                            (1 - blend_factor) * team_2_color_bgr[c]).astype(np.uint8)

    overlay = cv2.addWeighted(voronoi, opacity, pitch, 1 - opacity, 0)

    return overlay

# %%
import supervision as sv
from sports.annotators.soccer import (
    draw_pitch,
    draw_points_on_pitch,
    draw_pitch_voronoi_diagram
)

SOURCE_VIDEO_PATH = "121364_0.mp4"
BALL_ID = 0
GOALKEEPER_ID = 1
PLAYER_ID = 2
REFEREE_ID = 3

ellipse_annotator = sv.EllipseAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF', '#FF1493', '#FFD700']),
    thickness=2
)
label_annotator = sv.LabelAnnotator(
    color=sv.ColorPalette.from_hex(['#00BFFF', '#FF1493', '#FFD700']),
    text_color=sv.Color.from_hex('#000000'),
    text_position=sv.Position.BOTTOM_CENTER
)
triangle_annotator = sv.TriangleAnnotator(
    color=sv.Color.from_hex('#FFD700'),
    base=20, height=17
)

tracker = sv.ByteTrack()
tracker.reset()

frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)
frame = next(frame_generator)

# ball, goalkeeper, player, referee detection

result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
detections = sv.Detections.from_inference(result)

ball_detections = detections[detections.class_id == BALL_ID]
ball_detections.xyxy = sv.pad_boxes(xyxy=ball_detections.xyxy, px=10)

all_detections = detections[detections.class_id != BALL_ID]
all_detections = all_detections.with_nms(threshold=0.5, class_agnostic=True)
all_detections = tracker.update_with_detections(detections=all_detections)

goalkeepers_detections = all_detections[all_detections.class_id == GOALKEEPER_ID]
players_detections = all_detections[all_detections.class_id == PLAYER_ID]
referees_detections = all_detections[all_detections.class_id == REFEREE_ID]

# team assignment

players_crops = [sv.crop_image(frame, xyxy) for xyxy in players_detections.xyxy]
players_detections.class_id = team_classifier.predict(players_crops)

goalkeepers_detections.class_id = resolve_goalkeepers_team_id(
    players_detections, goalkeepers_detections)

referees_detections.class_id -= 1

all_detections = sv.Detections.merge([
    players_detections, goalkeepers_detections, referees_detections])

# frame visualization

labels = [
    f"#{tracker_id}"
    for tracker_id
    in all_detections.tracker_id
]

all_detections.class_id = all_detections.class_id.astype(int)

annotated_frame = frame.copy()
annotated_frame = ellipse_annotator.annotate(
    scene=annotated_frame,
    detections=all_detections)
annotated_frame = label_annotator.annotate(
    scene=annotated_frame,
    detections=all_detections,
    labels=labels)
annotated_frame = triangle_annotator.annotate(
    scene=annotated_frame,
    detections=ball_detections)

sv.plot_image(annotated_frame)

players_detections = sv.Detections.merge([
    players_detections, goalkeepers_detections
])

# detect pitch key points

result = FIELD_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
key_points = sv.KeyPoints.from_inference(result)

# project ball, players and referies on pitch

filter = key_points.confidence[0] > 0.5
frame_reference_points = key_points.xy[0][filter]
pitch_reference_points = np.array(CONFIG.vertices)[filter]

transformer = ViewTransformer(
    source=frame_reference_points,
    target=pitch_reference_points
)

frame_ball_xy = ball_detections.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
pitch_ball_xy = transformer.transform_points(points=frame_ball_xy)

players_xy = players_detections.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
pitch_players_xy = transformer.transform_points(points=players_xy)

referees_xy = referees_detections.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
pitch_referees_xy = transformer.transform_points(points=referees_xy)

# visualize video game-style radar view

annotated_frame = draw_pitch(CONFIG)
annotated_frame = draw_points_on_pitch(
    config=CONFIG,
    xy=pitch_ball_xy,
    face_color=sv.Color.WHITE,
    edge_color=sv.Color.BLACK,
    radius=10,
    pitch=annotated_frame)
annotated_frame = draw_points_on_pitch(
    config=CONFIG,
    xy=pitch_players_xy[players_detections.class_id == 0],
    face_color=sv.Color.from_hex('00BFFF'),
    edge_color=sv.Color.BLACK,
    radius=16,
    pitch=annotated_frame)
annotated_frame = draw_points_on_pitch(
    config=CONFIG,
    xy=pitch_players_xy[players_detections.class_id == 1],
    face_color=sv.Color.from_hex('FF1493'),
    edge_color=sv.Color.BLACK,
    radius=16,
    pitch=annotated_frame)
annotated_frame = draw_points_on_pitch(
    config=CONFIG,
    xy=pitch_referees_xy,
    face_color=sv.Color.from_hex('FFD700'),
    edge_color=sv.Color.BLACK,
    radius=16,
    pitch=annotated_frame)

sv.plot_image(annotated_frame)

# visualize voronoi diagram

annotated_frame = draw_pitch(CONFIG)
annotated_frame = draw_pitch_voronoi_diagram(
    config=CONFIG,
    team_1_xy=pitch_players_xy[players_detections.class_id == 0],
    team_2_xy=pitch_players_xy[players_detections.class_id == 1],
    team_1_color=sv.Color.from_hex('00BFFF'),
    team_2_color=sv.Color.from_hex('FF1493'),
    pitch=annotated_frame)

sv.plot_image(annotated_frame)

# visualize voronoi diagram with blend

annotated_frame = draw_pitch(
    config=CONFIG,
    background_color=sv.Color.WHITE,
    line_color=sv.Color.BLACK
)
annotated_frame = draw_pitch_voronoi_diagram_2(
    config=CONFIG,
    team_1_xy=pitch_players_xy[players_detections.class_id == 0],
    team_2_xy=pitch_players_xy[players_detections.class_id == 1],
    team_1_color=sv.Color.from_hex('00BFFF'),
    team_2_color=sv.Color.from_hex('FF1493'),
    pitch=annotated_frame)
annotated_frame = draw_points_on_pitch(
    config=CONFIG,
    xy=pitch_ball_xy,
    face_color=sv.Color.WHITE,
    edge_color=sv.Color.WHITE,
    radius=8,
    thickness=1,
    pitch=annotated_frame)
annotated_frame = draw_points_on_pitch(
    config=CONFIG,
    xy=pitch_players_xy[players_detections.class_id == 0],
    face_color=sv.Color.from_hex('00BFFF'),
    edge_color=sv.Color.WHITE,
    radius=16,
    thickness=1,
    pitch=annotated_frame)
annotated_frame = draw_points_on_pitch(
    config=CONFIG,
    xy=pitch_players_xy[players_detections.class_id == 1],
    face_color=sv.Color.from_hex('FF1493'),
    edge_color=sv.Color.WHITE,
    radius=16,
    thickness=1,
    pitch=annotated_frame)

sv.plot_image(annotated_frame)

# %% [markdown]
# ## Ball tracking

# %%
from collections import deque
import supervision as sv
from sports.annotators.soccer import draw_pitch, draw_points_on_pitch

SOURCE_VIDEO_PATH = "121364_0.mp4"
BALL_ID = 0
MAXLEN = 5

video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
frame_generator = sv.get_video_frames_generator(SOURCE_VIDEO_PATH)

path_raw = []
M = deque(maxlen=MAXLEN)

for frame in tqdm(frame_generator, total=video_info.total_frames):

    result = PLAYER_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
    detections = sv.Detections.from_inference(result)

    ball_detections = detections[detections.class_id == BALL_ID]
    ball_detections.xyxy = sv.pad_boxes(xyxy=ball_detections.xyxy, px=10)

    result = FIELD_DETECTION_MODEL.infer(frame, confidence=0.3)[0]
    key_points = sv.KeyPoints.from_inference(result)

    filter = key_points.confidence[0] > 0.5
    frame_reference_points = key_points.xy[0][filter]
    pitch_reference_points = np.array(CONFIG.vertices)[filter]

    transformer = ViewTransformer(
        source=frame_reference_points,
        target=pitch_reference_points
    )
    M.append(transformer.m)
    transformer.m = np.mean(np.array(M), axis=0)

    frame_ball_xy = ball_detections.get_anchors_coordinates(sv.Position.BOTTOM_CENTER)
    pitch_ball_xy = transformer.transform_points(points=frame_ball_xy)

    path_raw.append(pitch_ball_xy)

# %%
path = [
    np.empty((0, 2), dtype=np.float32) if coorinates.shape[0] >= 2 else coorinates
    for coorinates
    in path_raw
]

path = [coorinates.flatten() for coorinates in path]

# %%
from sports.annotators.soccer import draw_paths_on_pitch

annotated_frame = draw_pitch(CONFIG)
annotated_frame = draw_paths_on_pitch(
    config=CONFIG,
    paths=[path],
    color=sv.Color.WHITE,
    pitch=annotated_frame)

sv.plot_image(annotated_frame)

# %%
from typing import List, Union

def replace_outliers_based_on_distance(
    positions: List[np.ndarray],
    distance_threshold: float
) -> List[np.ndarray]:
    last_valid_position: Union[np.ndarray, None] = None
    cleaned_positions: List[np.ndarray] = []

    for position in positions:
        if len(position) == 0:
            # If the current position is already empty, just add it to the cleaned positions
            cleaned_positions.append(position)
        else:
            if last_valid_position is None:
                # If there's no valid last position, accept the first valid one
                cleaned_positions.append(position)
                last_valid_position = position
            else:
                # Calculate the distance from the last valid position
                distance = np.linalg.norm(position - last_valid_position)
                if distance > distance_threshold:
                    # Replace with empty array if the distance exceeds the threshold
                    cleaned_positions.append(np.array([], dtype=np.float64))
                else:
                    cleaned_positions.append(position)
                    last_valid_position = position

    return cleaned_positions

# %%
from sports.annotators.soccer import draw_paths_on_pitch

annotated_frame = draw_pitch(CONFIG)
annotated_frame = draw_paths_on_pitch(
    config=CONFIG,
    paths=[path],
    color=sv.Color.WHITE,
    pitch=annotated_frame)

sv.plot_image(annotated_frame)
